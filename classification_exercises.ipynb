# %% [markdown]
# # DATA ACQUISITION EXERCISES

# %%
# importing for later use
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) 
# containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# creating data frame using iris dataset from seaborn
df_iris = pd.DataFrame(sns.load_dataset('iris'))

#displaying dataframe
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# print the first 3 rows

# using head to print first 3 rows
df_iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# print the number of rows and columns (shape)

# using shape to print rows (150) and columns (5)
df_iris.shape
# Out:
# (150, 5)

# %%
# print the column names

# printing column names via .columns
df_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# print the data type of each column

# displaying data types via .info()
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# print the summary statistics for each of the numeric variables. 

# using .describe() to print summary statistics
df_iris.describe()

# Would you recommend rescaling the data based on these statistics?

# Answer: All of the numeric data in iris represents the same unit of measure (cm) so i won't scale them.
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Read the Table1_CustDetails table from the Excel_Exercises.xlsx file into a dataframe named df_excel

# creating dataframe using data from excel file
df_excel = pd.read_excel('Spreadsheets_Exercises.xlsx')

#displaying dataframe
df_excel
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
# assign the first 100 rows to a new dataframe, df_excel_sample

# displaying first 100 rows of dataframe via .head()
df_excel_sample = df_excel.head(100)

# displaying dataframe
df_excel_sample
# Out:
#    customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0   0002-ORFBO  Female                  0     Yes        Yes              1
# 1   0003-MKNFE    Male                  0      No         No              2
# 2   0004-TLHLJ    Male                  0      No         No              1
# 3   0011-IGKFF    Male                  1     Yes         No              1
# 4   0013-EXCHZ  Female                  1     Yes         No              1
# ..         ...     ...                ...     ...        ...            ...
# 95  0164-APGRB  Female                  0      No         No              2
# 96  0164-XAIRP  Female                  0      No         No              1
# 97  0168-XZKBB  Female                  0     Yes         No              2
# 98  0174-QRVVY    Male                  0     Yes        Yes              2
# 99  0177-PXBAT    Male                  1     Yes         No              2
#
# ...

# %%
# print the number of rows of your original dataframe

# printing number of rows via shape
# specifying 0 since shape returns (rows, columns) and we only want the first value, rows
df_excel.shape[0]
# Out:
# 7049

# %%
# print the first 5 column names

# using .columns with ":5" so that only the values in spaces 0-4 (the first 5 spaces) are printed
df_excel.columns[:5]
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %%
# print the column names that have a data type of object

# printing column names via creating a boolean mask for columns with a dtype of object
df_excel.dtypes[df_excel.dtypes == np.object]
# Out:
# customer_id     object
# gender          object
# partner         object
# dependents      object
# payment_type    object
# churn           object
# dtype: object

# %%
# compute the range for each of the numeric variables.

# creating variable that holds all columns with dtype of number (ie. columns with numerical data)
nv = df_excel.select_dtypes(np.number)

# calculating range by subtracting the min value from the max value of each numerical data column
nv_ranges = nv.max() - nv.min()

# display data frame
nv_ranges
# Out:
# is_senior_citizen       1.0
# phone_service           2.0
# internet_service        2.0
# contract_type           2.0
# monthly_charges       100.5
# total_charges        8666.0
# dtype: float64

# %%
# Read the data from this google sheet into a dataframe, df_google

# creating string that holds URL necessary for pd.read_csv to aqcuire data
test = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/export?format=csv&usp=sharing'
  
# using pd.read_csv to aqcuire data from URL provided
df_google = pd.read_csv(test)

# displaying 5 rows from dataframe
df_google.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# print the first 3 rows

# using .head to display first 3 rows
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# print the number of rows and columns

# using .shape to print rows (891) and columns(12)
df_google.shape
# Out:
# (891, 12)

# %%
# print the column names

# using .columns to print column names
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# print the data type of each column

# using .info() to print data type of each column
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# print the summary statistics for each of the numeric variables

# using .describe to print summary statistics of each numerical value
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# print the unique values for each of your categorical variables

# creating variable that holds the columns with data type of object
cv = df_google.select_dtypes(np.object)

# using nunique() to show count of unique values for each column
cv.nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %% [markdown]
# # DATA PREPARATION EXERCISES

# %% [markdown]
# ### Iris Data

# %%
# Use the function defined in acquire.py to load the iris data.
import acquire as ac

# loading iris data using acquire from external file
iris_df = ac.new_get_iris_data()

# displaying DF
iris_df
# Out:
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# ..          ...             ...           ...          ...           ...
# 145           3             146           6.7          3.0           5.2
# 146           3             147           6.3          2.5           5.0
# 147           3             148           6.5          3.0           5.2
# 148           3             149           6.2          3.4           5.4
# 149           3             150           5.9          3.0           5.1
#
#      petal_width species_name
# 0            0.2       setosa
# ...

# %%
# Drop the species_id and measurement_id columns.

# naming 2 columns to drop 
cols_to_drop = ['species_id', 'measurement_id']

# dropping the 2 chosen columns
iris_df = iris_df.drop(columns = cols_to_drop)

# displaying DF
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species_name
# 0             5.1          3.5           1.4          0.2       setosa
# 1             4.9          3.0           1.4          0.2       setosa
# 2             4.7          3.2           1.3          0.2       setosa
# 3             4.6          3.1           1.5          0.2       setosa
# 4             5.0          3.6           1.4          0.2       setosa
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3    virginica
# 146           6.3          2.5           5.0          1.9    virginica
# 147           6.5          3.0           5.2          2.0    virginica
# 148           6.2          3.4           5.4          2.3    virginica
# 149           5.9          3.0           5.1          1.8    virginica
#
# [150 rows x 5 columns]

# %%
# Rename the species_name column to just species.

# renaming column
iris_df.rename(columns={'species_name': 'species'}, inplace=True)

# displaying DF
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Create dummy variables of the species name.

# creating dummy DF for data in species column
dummy_df = pd.get_dummies(iris_df['species'], dummy_na = False)

# adding dummy DF to original DF
iris_df = pd.concat([iris_df, dummy_df], axis=1)

# displaying DF
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  setosa  \
# 0             5.1          3.5           1.4          0.2     setosa       1
# 1             4.9          3.0           1.4          0.2     setosa       1
# 2             4.7          3.2           1.3          0.2     setosa       1
# 3             4.6          3.1           1.5          0.2     setosa       1
# 4             5.0          3.6           1.4          0.2     setosa       1
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica       0
# 146           6.3          2.5           5.0          1.9  virginica       0
# 147           6.5          3.0           5.2          2.0  virginica       0
# 148           6.2          3.4           5.4          2.3  virginica       0
# 149           5.9          3.0           5.1          1.8  virginica       0
#
#      versicolor  virginica
# ...

# %%
# Create a function named prep_iris that accepts the untransformed iris data, 
# and returns the data with the transformations above applied.

# creating function that will change iris DF
def prep_iris(idf):
    # naming columns to drop
    cols_to_drop = ['species_id', 'measurement_id']
    # dropping named columns
    idf = idf.drop(columns = cols_to_drop)
    # renaming columns
    idf.rename(columns={'species_name': 'species'}, inplace=True)
    # creating dummy df with data from species column
    dummy_df = pd.get_dummies(idf['species'], dummy_na = False)
    # adding dummy df to original df
    idf = pd.concat([idf, dummy_df], axis=1)
    # returning df
    return idf

# using function to test success 
prep_iris(ac.new_get_iris_data())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  setosa  \
# 0             5.1          3.5           1.4          0.2     setosa       1
# 1             4.9          3.0           1.4          0.2     setosa       1
# 2             4.7          3.2           1.3          0.2     setosa       1
# 3             4.6          3.1           1.5          0.2     setosa       1
# 4             5.0          3.6           1.4          0.2     setosa       1
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica       0
# 146           6.3          2.5           5.0          1.9  virginica       0
# 147           6.5          3.0           5.2          2.0  virginica       0
# 148           6.2          3.4           5.4          2.3  virginica       0
# 149           5.9          3.0           5.1          1.8  virginica       0
#
#      versicolor  virginica
# ...

# %% [markdown]
# ### TITANIC DATA

# %%
# Use the function you defined in acquire.py to load the titanic data set.

# using acquire function to load frame
titanic_df = ac.new_get_titanic_data()

# displaying DF
titanic_df
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %%
# Handle the missing values in the embark_town and embarked columns.

# naming columns to drop
titanic_df  = titanic_df.drop(columns = 'embark_town')

# dropping named columns
titanic_df  = titanic_df[~titanic_df.embarked.isnull()]

# displaying DF
titanic_df
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  alone
# 0          S   Third  NaN      0
# ...

# %%
# Remove the deck column.

# dropping column
titanic_df = titanic_df.drop(columns = 'deck')

# displaying DF
titanic_df
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  alone
# 0          S   Third      0
# 1          C   First      0
# ...

# %%
# Create a dummy variable of the embarked column.

# creating dummy df with data from embarked column
dummy_df = pd.get_dummies(titanic_df['embarked'], dummy_na = False)

# attaching df to original df
titanic_df = pd.concat([titanic_df, dummy_df], axis=1)

# displaying DF
titanic_df
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  alone  C  Q  S
# 0          S   Third      0  0  0  1
# ...

# %%
# Scale the age and fare columns using a min max scaler. 

# importing scaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# creating variable to hold scaler function
scaler = MinMaxScaler()

# fitting and transforming data in age and far columns
titanic_df[['age', 'fare']] = scaler.fit_transform(titanic_df[['age', 'fare']])

# displaying DF
titanic_df
                 
# Why might this be beneficial?

# Answer: To handle situations where different units of measurement could lead to differences in weight. For example,
# we may have one feature measured in feet and another measured in centimeters

# When might you not want to do this?
# Answer: If the features all share the same units of measure
# Out:
#      passenger_id  survived  pclass     sex       age  sibsp  parch      fare  \
# 0               0         0       3    male  0.271174      1      0  0.014151
# 1               1         1       1  female  0.472229      1      0  0.139136
# 2               2         1       3  female  0.321438      0      0  0.015469
# 3               3         1       1  female  0.434531      1      0  0.103644
# 4               4         0       3    male  0.434531      0      0  0.015713
# ..            ...       ...     ...     ...       ...    ...    ...       ...
# 886           886         0       2    male  0.334004      0      0  0.025374
# 887           887         1       1  female  0.233476      0      0  0.058556
# 888           888         0       3  female       NaN      1      2  0.045771
# 889           889         1       1    male  0.321438      0      0  0.058556
# 890           890         0       3    male  0.396833      0      0  0.015127
#
# ...

# %%
# Fill the missing values in age. The way you fill these values is up to you. 
# Consider the tradeoffs of different methods.

# importing for use
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore")

# creating variable to hold simpleputer function with strategy set to most frequent
imputer = SimpleImputer(strategy = 'most_frequent')

# fitting imputer to the most frequent age in the age column
imputer = imputer.fit(titanic_df[['age']])

# updating all null values in age to the most frequent value in the column
titanic_df[['age']] = imputer.transform(titanic_df[['age']])

# displaying DF
titanic_df
# Out:
#      passenger_id  survived  pclass     sex       age  sibsp  parch      fare  \
# 0               0         0       3    male  0.271174      1      0  0.014151
# 1               1         1       1  female  0.472229      1      0  0.139136
# 2               2         1       3  female  0.321438      0      0  0.015469
# 3               3         1       1  female  0.434531      1      0  0.103644
# 4               4         0       3    male  0.434531      0      0  0.015713
# ..            ...       ...     ...     ...       ...    ...    ...       ...
# 886           886         0       2    male  0.334004      0      0  0.025374
# 887           887         1       1  female  0.233476      0      0  0.058556
# 888           888         0       3  female  0.296306      1      2  0.045771
# 889           889         1       1    male  0.321438      0      0  0.058556
# 890           890         0       3    male  0.396833      0      0  0.015127
#
# ...

# %%
# Create a function named prep_titanic that accepts the untransformed titanic data, 
# and returns the data with the transformations above applied.

# prep titanic data
def prep_titanic(tdf):
    # importing for use
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.impute import SimpleImputer
    import warnings
    warnings.filterwarnings("ignore")
    # dropping column
    tdf = tdf.drop(columns = 'embark_town')
    # removing rows with empty embarked value
    tdf = tdf[~tdf.embarked.isnull()]
    # dropping column
    tdf = tdf.drop(columns = 'deck')
    # creating dataframe with dummy values
    dummy_df = pd.get_dummies(tdf['embarked'], dummy_na = False)
    # adding dummy values to original data frame
    tdf = pd.concat([tdf, dummy_df], axis=1)
    # creating variable that holds minmaxscaler function
    scaler = MinMaxScaler()
    # fitting and transforming data in age and far columns
    tdf[['age', 'fare']] = scaler.fit_transform(tdf[['age', 'fare']])
    # setting variable with simple imputer set to most frequent
    imputer = SimpleImputer(strategy = 'most_frequent')
    # filling all age values that were empty with most frequent value from age column
    imputer = imputer.fit(tdf[['age']])
    tdf[['age']] = imputer.transform(tdf[['age']])
    # returning DF
    return tdf


prep_titanic(ac.new_get_titanic_data())
# Out:
#      passenger_id  survived  pclass     sex       age  sibsp  parch      fare  \
# 0               0         0       3    male  0.271174      1      0  0.014151
# 1               1         1       1  female  0.472229      1      0  0.139136
# 2               2         1       3  female  0.321438      0      0  0.015469
# 3               3         1       1  female  0.434531      1      0  0.103644
# 4               4         0       3    male  0.434531      0      0  0.015713
# ..            ...       ...     ...     ...       ...    ...    ...       ...
# 886           886         0       2    male  0.334004      0      0  0.025374
# 887           887         1       1  female  0.233476      0      0  0.058556
# 888           888         0       3  female  0.296306      1      2  0.045771
# 889           889         1       1    male  0.321438      0      0  0.058556
# 890           890         0       3    male  0.396833      0      0  0.015127
#
# ...

# %% [markdown]
# ### EXPLORATORY ANALYSIS

# %% [markdown]
# #### Split your data into train, test, and validate samples.

# %%
# importing for later use
from sklearn.model_selection import train_test_split

# creating new DF that is a copy of the prepped iris DF from the tidy data exercises
ex_iris = prep_iris(ac.new_get_iris_data())

# naming columns to drop
cols_to_drop = ['setosa', 'versicolor', 'virginica']

# dropping the 3 chosen columns since we won't need them
ex_iris = ex_iris.drop(columns = cols_to_drop)

# splitting DF into 2 separate DFs, 20% test, 80% train_validate 
train_validate, test = train_test_split(ex_iris, test_size = .2, random_state = 123, stratify = ex_iris.species)

# splitting train_validate into 2 DFs, 30% validate, 70% train
train, validate = train_test_split(train_validate, test_size = .3, random_state = 123, stratify = train_validate.species)

# displaying train DF
train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 79            5.7          2.6           3.5          1.0  versicolor
# 36            5.5          3.5           1.3          0.2      setosa
# 133           6.3          2.8           5.1          1.5   virginica
# 95            5.7          3.0           4.2          1.2  versicolor
# 18            5.7          3.8           1.7          0.3      setosa
# ..            ...          ...           ...          ...         ...
# 11            4.8          3.4           1.6          0.2      setosa
# 85            6.0          3.4           4.5          1.6  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# 44            5.1          3.8           1.9          0.4      setosa
# 73            6.1          2.8           4.7          1.2  versicolor
#
# [84 rows x 5 columns]

# %% [markdown]
# #### Create a swarmplot using a melted dataframe of all your numeric variables.
# #### The x-axis should be the variable name, the y-axis is the measure.
# #### Add another dimension using color to represent species.
# #### Document takeaways from this visualization.

# %%
# importing for later use
import seaborn as sns
import matplotlib.pyplot as plt

# setting size of figure 
plt.figure(figsize = (8,7))
# setting palette and style
sns.set(style="whitegrid", palette="muted")

# creating melted DF
# the species column will remain the same but 2 new column, measurement and value will be added
# all of the length and width column names will be listed under measurement
# value will hold the length and width values for each row
melt = train.melt(id_vars= 'species', var_name = "measurement")

# creating swarmplot
# x axis is measurement, y axis is value
sns.swarmplot(x = "measurement", y = "value", data = melt, hue="species", palette="Set2")
# display legend
plt.legend()

# %% [markdown]
# #### Create 4 subplots (2 rows x 2 columns) of scatterplots.
#
# #### sepal_length x sepal_width
# #### petal_length x petal_width
# #### sepal_area x petal_area
# #### sepal_length x petal_length
# #### What are your takeaways?

# %%
# creating two dataframes
# each respectively holds the petal and sepal areas for each row of the train df
petal_area = pd.DataFrame(train['petal_length'] * train['petal_width'])
sepal_area = pd.DataFrame(train['sepal_length'] * train['sepal_width'])

# renaming columns to reflect their values
petal_area.rename(columns={0:'petal_area'}, inplace=True)
sepal_area.rename(columns={0:'sepal_area'}, inplace=True)

# add the new DFs to our existing train DF
train_w_area = pd.concat([petal_area, train], axis = 1)
train_w_area = pd.concat([sepal_area, train_w_area], axis = 1)

# creatin 4 plots to display different combinations of measurements
fig, axs = plt.subplots(2, 2, figsize=(16, 9))
sns.scatterplot(ax=axs[0,0], x='sepal_length', y='sepal_width', hue='species', data=train_w_area)
sns.scatterplot(ax=axs[0,1], x='petal_length', y='petal_width', hue='species', data=train_w_area)
sns.scatterplot(ax=axs[1,0], x='sepal_area', y='petal_area', hue='species', data=train_w_area)
sns.scatterplot(ax=axs[1,1], x='sepal_length', y='petal_length', hue='species', data=train_w_area)

# Takeaways: 
# 1) Versicolor and virginica tend to have values that are closer together than setosa.
# 2) Setosas have wider but shorter sepals than the other two
# 3) Setosas tend to have much smaller petals than the other two both in regards to length and width

# %% [markdown]
# #### Create a heatmap of each variable layering correlation coefficient on top.

# %%
# creating heatmap for each variable
sns.heatmap(train.corr(), cmap='coolwarm', center = 0, annot=True)

# %% [markdown]
# #### Create a scatter matrix visualizing the interaction of each variable

# %%
# setting figure size
plt.figure(figsize=(12,10))

# creating pairplot using train DF
sns.pairplot(train, hue='species')

# %% [markdown]
# #### Is the sepal length significantly different in virginica compared to versicolor?
# #### Run a statistical experiment to test this.
# #### Make sure to include a null hypothesis, alternative hypothesis, results, and summary.

# %%
import scipy.stats as stats

# Hypothesis:
# H0: Virginica sepal legnths are not different than versicolor ones
# Ha: Virginica sepal legnths are different than versicolor ones

# Results
# setting alpha to represent alpha
alpha = .05

# creating 2 data frames that hold the sepal lengths for virginica and versicolor respectively
virginica_sl = train[train['species'] == 'virginica']['sepal_length']
versicolor_sl = train[train['species'] == 'versicolor']['sepal_length']

# calculating t and p value to determine if we reject or fail to reject H0
t, p = stats.ttest_ind(virginica_sl, versicolor_sl, equal_var = False)
t, p

# Summary
# We performed a 2 sample, 2 tailed test and found p to be less than alpha
# With this information, we reject the null hypothesis 
# that virginica sepal lengths are not different than versicolor ones
# Out:
# (5.656491804882077, 6.856736413800083e-07)

# %% [markdown]
# #### What is your takeaway from this statistical testing?

# %%
# Answer: My takeaway is that the sepal lengths of virginicas are different than versicolors on average.
# Given that the t value was so high, this indicates that they are probably longer on average.

# %% [markdown]
# #### Create any other visualizations and run any other statistical tests you think will be helpful
# #### in exploring this data set.

# %%
# Question: Are virginica sepals bigger than the overall average sepal area of all iris'?

# Hypothesis
# H0: mean of virginica sepal areas = mean of all iris sepal areas
# Ha: mean of virginica sepal areas > mean of all iris sepal areas

# Results
# setting alpha to represent alpha
alpha = .05

# creating 2 data frames that hold the sepal lengths for virginica and versicolor respectively
virginica_sa = train_w_area[train_w_area['species'] == 'virginica']['sepal_area']
overall_sa = train_w_area.sepal_area.mean()

# calculating t and p value to determine if we reject or fail to reject H0
t, p = stats.ttest_1samp(virginica_sa, overall_sa)
t, p/2

# Summary
# We performed a 1 sample, 1 tailed test and found p/2 to be less than alpha
# With this information, we reject the null hypothesis 
# that virginica sepal areas = mean of all iris sepal areas
# our takeaway is that there is evidence that virginica sepals are larger on average than sepals of the other 2 species
# Out:
# (2.7316831748177006, 0.00548478800078824)

# %%
# creating box plot of each species' petal area
sns.boxplot(data = train_w_area, y='sepal_area', x='species')

# our box plot reinforces our findings that virginica sepals are larger on average than the other 2 species
