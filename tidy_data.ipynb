# %%
import pandas as pd

# %%
attendance_df = pd.read_csv('attendance.csv')

attendance_df
# Out:
#   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P

# %%
attendance_df = attendance_df.replace('P',1)
attendance_df = attendance_df.replace('H',.5)
attendance_df = attendance_df.replace('T',.9)
attendance_df = attendance_df.replace('A',0)

attendance_df.head()
# Out:
#   Unnamed: 0  2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  \
# 0      Sally           1         0.9         0.9         0.5         1.0
# 1       Jane           0         1.0         0.9         0.9         0.9
# 2      Billy           0         0.9         0.0         0.0         0.5
# 3       John           1         0.9         0.5         1.0         1.0
#
#    2018-01-06  2018-01-07  2018-01-08
# 0         0.0         0.9         0.9
# 1         0.9         0.0         0.9
# 2         0.9         1.0         0.9
# 3         0.9         1.0         1.0

# %%
total = attendance_df.sum(axis=1)

total
# Out:
# 0    6.1
# 1    5.5
# 2    4.2
# 3    7.3
# dtype: float64

# %%
days = (attendance_df.count(axis=1))-1

days
# Out:
# 0    8
# 1    8
# 2    8
# 3    8
# dtype: int64

# %%
attendance_df['percentage'] = round((total/days) * 100, 2)

attendance_df
# Out:
#   Unnamed: 0  2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  \
# 0      Sally           1         0.9         0.9         0.5         1.0
# 1       Jane           0         1.0         0.9         0.9         0.9
# 2      Billy           0         0.9         0.0         0.0         0.5
# 3       John           1         0.9         0.5         1.0         1.0
#
#    2018-01-06  2018-01-07  2018-01-08  percentage
# 0         0.0         0.9         0.9       76.25
# 1         0.9         0.0         0.9       68.75
# 2         0.9         1.0         0.9       52.50
# 3         0.9         1.0         1.0       91.25

# %%
attendance_df = attendance_df.rename(columns = {'Unnamed: 0': 'student'})

# %%
attendance_df = attendance_df[['student', 'percentage']]

attendance_df
# Out:
#   student  percentage
# 0   Sally       76.25
# 1    Jane       68.75
# 2   Billy       52.50
# 3    John       91.25
